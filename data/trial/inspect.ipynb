# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data=np.load("/its/home/drs25/ant_trajectory/data/trial/trial2025-05-15 14:57:11.862532.npy")

# %%
data[:,0,:]
# Out:
# array([[0.08, 0.6 ],
#        [0.08, 0.6 ],
#        [0.08, 0.6 ],
#        [0.08, 0.6 ]])

# %%
for i in range(len(data)):
    plt.plot(data[i][:,0],data[i][:,1])
plt.show()
